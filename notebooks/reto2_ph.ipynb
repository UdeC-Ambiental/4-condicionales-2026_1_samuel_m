# %% [markdown]
# # 🧩 Reto 2 – pH
# **Objetivo:** clasificar pH y generar alerta química.
#
# **Datos:** `../data/muestras_calidad_agua.csv`

# %% [markdown]
# ### Pasos
# 1. Carga el CSV en `df`.
# 2. Extrae `sitio` y `pH`.
# 3. Crea `clasificacion_pH` con tres rangos.
# 4. Crea `alerta_quimica` (revisión si pH < 6.5 o pH > 8.5).
# 5. Filtra `df_alerta` y exporta `resultado_ph.csv`.
#
# > **Reto adicional:** promedio y desviación estándar.

# %%
# Abrir el archivo CSV
with open('../data/muestras_calidad_agua.csv', 'r') as archivo:
    lineas = archivo.readlines()

# Mostrar encabezado
print("Encabezado:")
print(lineas[0])

print("\nResultados de alerta química:\n")

# Recorrer cada fila (desde la segunda)
for linea in lineas[1:]:
    datos = linea.strip().split(',')

    sitio = datos[0]
    ph = float(datos[1])

    # Condicionales
    if ph < 6.5:
        print(sitio, "-", ph, "⚠️ ALERTA: Agua Ácida")
    elif ph > 8.5:
        print(sitio, "-", ph, "⚠️ ALERTA: Agua Alcalina")
    else:
        print(sitio, "-", ph, "✅ pH Aceptable")
# Out:
# Encabezado:
# sitio,pH,oxigeno,temperatura
#
#
# Resultados de alerta química:
#
# RÃ­o Subachoque - 7.2 ✅ pH Aceptable
# Quebrada Honda (FacatativÃ¡) - 6.3 ⚠️ ALERTA: Agua Ácida
# RÃ­o Botello (Madrid) - 6.8 ✅ pH Aceptable
# Afluente San JosÃ© (El Rosal) - 7.9 ✅ pH Aceptable
# RÃ­o Villeta - 8.7 ⚠️ ALERTA: Agua Alcalina
# Quebrada Cune (San Francisco) - 6.0 ⚠️ ALERTA: Agua Ácida
# RÃ­o Tobia (Nocaima) - 7.4 ✅ pH Aceptable
# Quebrada Negra (La Vega) - 7.6 ✅ pH Aceptable
# RÃ­o BahamÃ³n (Sasaima) - 8.1 ✅ pH Aceptable
# RÃ­o Guayuriba (La Mesa) - 5.9 ⚠️ ALERTA: Agua Ácida
